# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os


project_root = os.path.abspath(os.path.join(os.getcwd(), "..", "src"))
if project_root not in sys.path:
    sys.path.append(project_root)

from ProcesadorEDA import ProcesadorEDA
from GestorBaseDatos import GestorBaseDatos

# %%
GestorDB = GestorBaseDatos()
GestorDB.CargaDatos("C:/Users/rmont/OneDrive/Escritorio/dddd/ProyectoII-SegExamen-main/ProyectoII-SegExamen-main/Proyecto II/la_liga_insights/data/partidos-laliga-2024-2025.csv")
df = GestorDB.ObtencionDatos()
procesador = ProcesadorEDA(df)

# %%
procesador.mostrar_head()
# Out:
#    id_partido  temporada       fecha equipo_local equipo_visita  goles_local  \
# 0           1       2024  2024-08-15   Ath Bilbao        Getafe            1
# 1           2       2024  2024-08-15        Betis        Girona            1
# 2           3       2024  2024-08-16        Celta        Alaves            2
# 3           4       2024  2024-08-16   Las Palmas       Sevilla            2
# 4           5       2024  2024-08-17      Osasuna       Leganes            1
#
#    goles_visita xg_local xg_visita posesion_local  ... rojas_local  \
# 0             1     None      None           None  ...           0
# 1             1     None      None           None  ...           0
# 2             1     None      None           None  ...           0
# 3             2     None      None           None  ...           0
# 4             1     None      None           None  ...           0
#
#    rojas_visita  tiros_local  tiros_visita  tiros_a_puerta_local  \
# ...

# %%
procesador.mostrar_tail()
# Out:
#      id_partido  temporada       fecha equipo_local equipo_visita  \
# 375         376       2024  2025-05-24       Getafe         Celta
# 376         377       2024  2025-05-24    Vallecano      Mallorca
# 377         378       2024  2025-05-25       Girona    Ath Madrid
# 378         379       2024  2025-05-25   Villarreal       Sevilla
# 379         380       2024  2025-05-25   Ath Bilbao     Barcelona
#
#      goles_local  goles_visita xg_local xg_visita posesion_local  ...  \
# 375            1             2     None      None           None  ...
# 376            0             0     None      None           None  ...
# 377            0             4     None      None           None  ...
# 378            4             2     None      None           None  ...
# 379            0             3     None      None           None  ...
#
#     rojas_local  rojas_visita  tiros_local  tiros_visita  \
# 375           1             0            6            15
# ...

# %%
procesador.mostrar_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_partido             380 non-null    int64
#  1   temporada              380 non-null    int64
#  2   fecha                  380 non-null    object
#  3   equipo_local           380 non-null    object
#  4   equipo_visita          380 non-null    object
#  5   goles_local            380 non-null    int64
#  6   goles_visita           380 non-null    int64
#  7   xg_local               0 non-null      object
#  8   xg_visita              0 non-null      object
#  9   posesion_local         0 non-null      object
#  10  posesion_visita        0 non-null      object
#  11  amarillas_local        380 non-null    int64
#  12  amarillas_visita       380 non-null    int64
#  13  rojas_local            380 non-null    int64
# ...

# %%
procesador.mostrar_dimensiones()
# Out:
# (380, 23)

# %%
procesador.mostrar_valores_nulos()
# Out:
# id_partido                 0
# temporada                  0
# fecha                      0
# equipo_local               0
# equipo_visita              0
# goles_local                0
# goles_visita               0
# xg_local                 380
# xg_visita                380
# posesion_local           380
# posesion_visita          380
# amarillas_local            0
# amarillas_visita           0
# rojas_local                0
# rojas_visita               0
# tiros_local                0
# tiros_visita               0
# tiros_a_puerta_local       0
# tiros_a_puerta_visita      0
# corners_local              0
# corners_visita             0
# faltas_local               0
# faltas_visita              0
# dtype: int64

# %%
procesador.limpiar_datos()
# Out:
#      id_partido  temporada       fecha equipo_local equipo_visita  \
# 0             1       2024  2024-08-15   Ath Bilbao        Getafe
# 1             2       2024  2024-08-15        Betis        Girona
# 2             3       2024  2024-08-16        Celta        Alaves
# 3             4       2024  2024-08-16   Las Palmas       Sevilla
# 4             5       2024  2024-08-17      Osasuna       Leganes
# ..          ...        ...         ...          ...           ...
# 375         376       2024  2025-05-24       Getafe         Celta
# 376         377       2024  2025-05-24    Vallecano      Mallorca
# 377         378       2024  2025-05-25       Girona    Ath Madrid
# 378         379       2024  2025-05-25   Villarreal       Sevilla
# 379         380       2024  2025-05-25   Ath Bilbao     Barcelona
#
#      goles_local  goles_visita  amarillas_local  amarillas_visita  \
# 0              1             1                4                 1
# ...

# %%
procesador.eliminar_columnas('temporada')
# Out:
# Columnas eliminadas: temporada
#      id_partido       fecha equipo_local equipo_visita  goles_local  \
# 0             1  2024-08-15   Ath Bilbao        Getafe            1
# 1             2  2024-08-15        Betis        Girona            1
# 2             3  2024-08-16        Celta        Alaves            2
# 3             4  2024-08-16   Las Palmas       Sevilla            2
# 4             5  2024-08-17      Osasuna       Leganes            1
# ..          ...         ...          ...           ...          ...
# 375         376  2025-05-24       Getafe         Celta            1
# 376         377  2025-05-24    Vallecano      Mallorca            0
# 377         378  2025-05-25       Girona    Ath Madrid            0
# 378         379  2025-05-25   Villarreal       Sevilla            4
# 379         380  2025-05-25   Ath Bilbao     Barcelona            0
#
#      goles_visita  amarillas_local  amarillas_visita  rojas_local  \
# ...

# %%
procesador.mostrar_valores_nulos()
# Out:
# id_partido               0
# fecha                    0
# equipo_local             0
# equipo_visita            0
# goles_local              0
# goles_visita             0
# amarillas_local          0
# amarillas_visita         0
# rojas_local              0
# rojas_visita             0
# tiros_local              0
# tiros_visita             0
# tiros_a_puerta_local     0
# tiros_a_puerta_visita    0
# corners_local            0
# corners_visita           0
# faltas_local             0
# faltas_visita            0
# dtype: int64

# %%
procesador.mostrar_resumen_descriptivo()
# Out:
#        id_partido  goles_local  goles_visita  amarillas_local  \
# count  380.000000   380.000000    380.000000       380.000000
# mean   190.500000     1.452632      1.165789         2.157895
# std    109.840794     1.243609      1.075703         1.473178
# min      1.000000     0.000000      0.000000         0.000000
# 25%     95.750000     1.000000      0.000000         1.000000
# 50%    190.500000     1.000000      1.000000         2.000000
# 75%    285.250000     2.000000      2.000000         3.000000
# max    380.000000     7.000000      5.000000         7.000000
#
#        amarillas_visita  rojas_local  rojas_visita  tiros_local  tiros_visita  \
# count        380.000000   380.000000    380.000000   380.000000    380.000000
# mean           2.323684     0.102632      0.102632    13.121053     10.571053
# std            1.609001     0.328896      0.320773     5.764149      4.648909
# min            0.000000     0.000000      0.000000     2.000000      0.000000
# ...

# %%
procesador.matriz_correlacion()
# Out:
#                        id_partido  goles_local  goles_visita  amarillas_local  \
# id_partido               1.000000    -0.021866      0.051618        -0.104797
# goles_local             -0.021866     1.000000     -0.022713        -0.106802
# goles_visita             0.051618    -0.022713      1.000000         0.126627
# amarillas_local         -0.104797    -0.106802      0.126627         1.000000
# amarillas_visita        -0.101333    -0.043084     -0.009744         0.252214
# rojas_local              0.024065    -0.126777      0.123309         0.140726
# rojas_visita            -0.051634     0.048597     -0.026502         0.049370
# tiros_local              0.057860     0.290849     -0.086224        -0.187757
# tiros_visita             0.031243    -0.152988      0.287035         0.143986
# tiros_a_puerta_local     0.042199     0.549903     -0.040544        -0.145210
# tiros_a_puerta_visita    0.077518    -0.037894      0.617196         0.056391
# ...

# %%
procesador.mostrar_columnas()
# Out:
# Index(['id_partido', 'fecha', 'equipo_local', 'equipo_visita', 'goles_local',
#        'goles_visita', 'amarillas_local', 'amarillas_visita', 'rojas_local',
#        'rojas_visita', 'tiros_local', 'tiros_visita', 'tiros_a_puerta_local',
#        'tiros_a_puerta_visita', 'corners_local', 'corners_visita',
#        'faltas_local', 'faltas_visita'],
#       dtype='object')

# %%
procesador.outliers('faltas_local')
