# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", "src"))
if project_root not in sys.path:
    sys.path.append(project_root)

from ProcesadorEDA import ProcesadorEDA
from GestorBaseDatos import GestorBaseDatos
from Visualizador import Visualizador
import pandas as pd
# Out:
# ['SQL Server', 'SQL Server Native Client RDA 11.0', 'ODBC Driver 17 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
GestorDB = GestorBaseDatos()
GestorDB.CargaDatos("C:/Users/rmont/OneDrive/Escritorio/dddd/ProyectoII-SegExamen-main/ProyectoII-SegExamen-main/Proyecto II/la_liga_insights/data/partidos-laliga-2024-2025.csv")
df = GestorDB.ObtencionDatos()

# %%
procesador = ProcesadorEDA(df)

# Limpiar los datos
df_limpio = procesador.limpiar_datos()
df_limpio = procesador.eliminar_columnas(['temporada'])
visualizador = Visualizador(df_limpio)
# Out:
# Columnas eliminadas: ['temporada']

# %%
# Ver nombres de columnas
df_limpio.columns
# Out:
# Index(['id_partido', 'fecha', 'equipo_local', 'equipo_visita', 'goles_local',
#        'goles_visita', 'amarillas_local', 'amarillas_visita', 'rojas_local',
#        'rojas_visita', 'tiros_local', 'tiros_visita', 'tiros_a_puerta_local',
#        'tiros_a_puerta_visita', 'corners_local', 'corners_visita',
#        'faltas_local', 'faltas_visita'],
#       dtype='object')

# %%
# Grafico histograma
visualizador.mostrar_histograma('goles_visita')

# %%
# Grafico histograma
visualizador.mostrar_histograma('goles_local')

# %%
# Ver nombres de columnas
df_limpio.columns
# Out:
# Index(['id_partido', 'fecha', 'equipo_local', 'equipo_visita', 'goles_local',
#        'goles_visita', 'amarillas_local', 'amarillas_visita', 'rojas_local',
#        'rojas_visita', 'tiros_local', 'tiros_visita', 'tiros_a_puerta_local',
#        'tiros_a_puerta_visita', 'corners_local', 'corners_visita',
#        'faltas_local', 'faltas_visita'],
#       dtype='object')

# %%
# Grafico Scatter
visualizador.mostrar_scatter('tiros_local', 'tiros_visita')

# %%
# Grafico Scatter
visualizador.mostrar_scatter('tiros_local', 'tiros_a_puerta_local')

# %%
# Grafico Scatter
visualizador.mostrar_scatter('tiros_visita', 'tiros_a_puerta_visita')

# %%
# Grafico Scatter
visualizador.mostrar_scatter('faltas_visita', 'faltas_local')

# %%
# Ver nombres de columnas
df_limpio.columns
# Out:
# Index(['id_partido', 'fecha', 'equipo_local', 'equipo_visita', 'goles_local',
#        'goles_visita', 'amarillas_local', 'amarillas_visita', 'rojas_local',
#        'rojas_visita', 'tiros_local', 'tiros_visita', 'tiros_a_puerta_local',
#        'tiros_a_puerta_visita', 'corners_local', 'corners_visita',
#        'faltas_local', 'faltas_visita'],
#       dtype='object')

# %%
# Grafico de Barras
visualizador.mostrar_grafico_barras('corners_local')  # Boxplot para detectar outliers

# %%
# Grafico de barras
visualizador.mostrar_grafico_barras('faltas_local')

# %%
# Ver nombres de columnas
df_limpio.columns
# Out:
# Index(['id_partido', 'fecha', 'equipo_local', 'equipo_visita', 'goles_local',
#        'goles_visita', 'amarillas_local', 'amarillas_visita', 'rojas_local',
#        'rojas_visita', 'tiros_local', 'tiros_visita', 'tiros_a_puerta_local',
#        'tiros_a_puerta_visita', 'corners_local', 'corners_visita',
#        'faltas_local', 'faltas_visita'],
#       dtype='object')

# %%
# Grafico Barras horizontal
visualizador.mostrar_barras_horizontal('amarillas_local')

# %%
# Grafico Barras horizontal
visualizador.mostrar_barras_horizontal('amarillas_visita')
